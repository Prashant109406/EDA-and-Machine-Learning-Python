# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

mu, sigma = 3, 2 

s = np.random.normal(mu, sigma, 10000)
s.sort()

# Fit a normal distribution to the data:

# Plot the histogram.
plt.hist(s, bins=20, density=True, alpha=0.6)

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
sample_mean, sample_sigma = 1.5, 2
sample = np.random.normal(sample_mean, sample_sigma, 200)
sample.sort()

# %%
ci_s=norm.interval(0.95,sample_mean,sample_sigma)
count, bins, ignored = plt.hist(s, 30, alpha=0.1, density=True)
plt.plot(s,norm.pdf(s,mu,sigma),color="blue")
sample_count, sample_bins, sample_ignored = plt.hist(sample, 30, alpha=0.1, density=True)
plt.plot(sample,norm.pdf(sample,sample_mean,sample_sigma),color="red")
plt.axvline(ci_s[0],color='g')
plt.axvline(ci_s[1],color='g')

# %%
count, bins, ignored = plt.hist(s, 30, alpha=0.1, density=True)
plt.plot(s,norm.pdf(s,mu,sigma),color="blue")
count, bins, ignored = plt.hist(sample, 30, alpha=0.1, density=True)
plt.plot(sample,norm.pdf(sample,sample_mean,sample_sigma),color="red")
plt.axvline(ci_s[0],color='g')
plt.axvline(ci_s[1],color='g')
plt.fill_between(x=np.arange(-4,ci_s[0],0.01), 
                 y1= norm.pdf(np.arange(-4,ci_s[0],0.01),sample_mean,sample_sigma) ,
                 facecolor='red',
                 alpha=0.35)

plt.fill_between(x=np.arange(ci_s[1],7.5,0.01), 
                 y1= norm.pdf(np.arange(ci_s[1],7.5,0.01),sample_mean,sample_sigma) ,
                 facecolor='red',
                 alpha=0.5)

plt.fill_between(x=np.arange(ci_s[0],ci_s[1],0.01), 
                 y1= norm.pdf(np.arange(ci_s[0],ci_s[1],0.01),loc=3, scale=2) ,
                 facecolor='blue',
                 alpha=0.5)

plt.text(x=0, y=0.20, s= "Null Hypothesis")
plt.text(x=7.5, y=0.05, s= "Alternative")
plt.text(x=-4, y=0.01, s= "Type 1 Error")
plt.text(x=6, y=0.01, s= "Type 1 Error")
plt.text(x=2, y=0.02, s= "Type 2 Error")

plt.show()

# %%
z_score=(sample_mean-mu)/sigma
p_value = norm.sf(abs(z_score))
print('P-value= {}'.format(p_value))
if p_value<0.05:
    print('P-value<alpha rejecting hypothesis')
else:
    print('P-value>alpha not rejecting hypothesis')
# Out:
# P-value= 0.2266273523768682
# P-value>alpha not rejecting hypothesis
